# %%
import pandas as pd # type: ignore
import numpy as np # type: ignore

df = pd.read_csv('E:/learning/UT DataScience/Python for Data Science/Session 1/Heart data.csv')
df
# Out:
#      Age (age in year)  sex  chest pain  blood pressure  cholestoral   \
# 0                   63    1           1           145.0         233.0
# 1                   37    1           3           130.0         250.0
# 2                   41    0           2           130.0         204.0
# 3                   56    1           2           120.0         236.0
# 4                   57    0           4           120.0         354.0
# 5                   57    1           4           140.0         192.0
# 6                   56    0           2           140.0         294.0
# 7                   44    1           2           120.0         263.0
# 8                   52    1           3           172.0         199.0
# 9                   57    1           3           150.0         168.0
# 10                  54    1           4           140.0         239.0
# 11                  48    0           3           130.0         275.0
# ...

# %%
print('Our data has {0} rows and {1} columns'.format(df.shape[0], df.shape[1]))
print('are there missing values? {}'.format(df.isnull().any().any()))
df.describe()
# Out:
# Our data has 597 rows and 14 columns
# are there missing values? True
#        Age (age in year)         sex  chest pain  blood pressure  \
# count         597.000000  597.000000  597.000000      596.000000
# mean           51.182580    0.701843    3.072027      132.129195
# std             9.074366    0.457833    0.965776       17.603812
# min            28.000000    0.000000    1.000000       92.000000
# 25%            44.000000    0.000000    2.000000      120.000000
# 50%            52.000000    1.000000    3.000000      130.000000
# 75%            58.000000    1.000000    4.000000      140.000000
# max            77.000000    1.000000    4.000000      200.000000
#
#        cholestoral   blood sugar  electrocardiographic   heart rate  \
# count    574.000000   589.000000             596.000000  596.000000
# mean     248.655052     0.110357               0.610738  144.456376
# std       59.784805     0.313600               0.869358   23.794282
# ...

# %%
df.shape
# Out:
# (597, 14)

# %%
len(df)
# Out:
# 597

# %% [markdown]
# Show Complete & All DataFrame

# %%
# pd.set_option('display.max_rows', None, 'display.max_columns', None)
# df

# %% [markdown]
# Data Manipulation

# %%
df.columns
# Out:
# Index(['Age (age in year)', 'sex', 'chest pain', 'blood pressure',
#        'cholestoral ', 'blood sugar', 'electrocardiographic ', 'heart rate',
#        'exercise induced', 'depression ', 'slope', 'ca', 'thal', 'c'],
#       dtype='object')

# %%
df = df.rename(columns= {'Age (age in year)' : "age", "cholestoral " : "ch" })
list (df.columns)
# Out:
# ['age',
#  'sex',
#  'chest pain',
#  'blood pressure',
#  'ch',
#  'blood sugar',
#  'electrocardiographic ',
#  'heart rate',
#  'exercise induced',
#  'depression ',
#  'slope',
#  'ca',
#  'thal',
#  'c']

# %% [markdown]
# Data Subsetting

# %%
df[['chest pain', 'c']].head(3)
# Out:
#    chest pain  c
# 0           1  0
# 1           3  0
# 2           2  0

# %%
df['blood pressure'].isin([120,130])
# Out:
# 0      False
# 1       True
# 2       True
# 3       True
# 4       True
# 5      False
# 6      False
# 7       True
# 8      False
# 9      False
# 10     False
# 11      True
# 12      True
# 13     False
# 14     False
# 15      True
# 16      True
# 17     False
# 18     False
# 19     False
# 20     False
# 21      True
# 22     False
# 23     False
# 24     False
# 25     False
# 26     False
# 27     False
# 28     False
# 29      True
# 30     False
# 31      True
# 32      True
# 33     False
# 34     False
# 35     False
# 36     False
# 37     False
# 38     False
# 39     False
# 40     False
# 41      True
# 42     False
# 43      True
# 44     False
# 45      True
# 46     False
# 47     False
# 48     False
# 49     False
# 50      True
# 51      True
# 52      True
# 53     False
# 54     False
# 55     False
# 56     False
# 57     False
# 58     False
# 59     False
# 60     False
# 61     False
# 62     False
# 63     False
# 64     False
# 65     False
# ...

# %%
df[df['thal'].isin([4,6,7])]
# Out:
#      age  sex  chest pain  blood pressure     ch  blood sugar  \
# 0     63    1           1           145.0  233.0          1.0
# 5     57    1           4           140.0  192.0          0.0
# 7     44    1           2           120.0  263.0          0.0
# 8     52    1           3           172.0  199.0          1.0
# 20    59    1           4           135.0  234.0          0.0
# 24    40    1           1           140.0  199.0          0.0
# 31    65    1           4           120.0  177.0          0.0
# 37    54    1           3           150.0  232.0          0.0
# 52    62    1           3           130.0  231.0          0.0
# 61    54    1           2           108.0  309.0          0.0
# 62    52    1           1           118.0  186.0          0.0
# 63    41    1           2           135.0  203.0          0.0
# 70    54    1           3           120.0  258.0          0.0
# 71    51    1           3            94.0  227.0          0.0
# ...

# %%
np.logical_not(df['blood pressure'].isin([120,130]))
# Out:
# 0       True
# 1      False
# 2      False
# 3      False
# 4      False
# 5       True
# 6       True
# 7      False
# 8       True
# 9       True
# 10      True
# 11     False
# 12     False
# 13      True
# 14      True
# 15     False
# 16     False
# 17      True
# 18      True
# 19      True
# 20      True
# 21     False
# 22      True
# 23      True
# 24      True
# 25      True
# 26      True
# 27      True
# 28      True
# 29     False
# 30      True
# 31     False
# 32     False
# 33      True
# 34      True
# 35      True
# 36      True
# 37      True
# 38      True
# 39      True
# 40      True
# 41     False
# 42      True
# 43     False
# 44      True
# 45     False
# 46      True
# 47      True
# 48      True
# 49      True
# 50     False
# 51     False
# 52     False
# 53      True
# 54      True
# 55      True
# 56      True
# 57      True
# 58      True
# 59      True
# 60      True
# 61      True
# 62      True
# 63      True
# 64      True
# 65      True
# ...

# %% [markdown]
# Data Cutting

# %%
df.iloc[200:300, 4:8].head(3)
# Out:
#         ch  blood sugar  electrocardiographic   heart rate
# 200  180.0          0.0                    0.0       140.0
# 201  194.0          0.0                    0.0       170.0
# 202  365.0          0.0                    1.0       134.0

# %%
df.loc[3:9 , ["age" ,"chest pain"]  ]
# Out:
#    age  chest pain
# 3   56           2
# 4   57           4
# 5   57           4
# 6   56           2
# 7   44           2
# 8   52           3
# 9   57           3

# %%
df.iloc[-10:,2:5]
# Out:
#      chest pain  blood pressure     ch
# 587           4           140.0  341.0
# 588           4           160.0  291.0
# 589           4           155.0  342.0
# 590           4           128.0  212.0
# 591           4           140.0  231.0
# 592           4           140.0  266.0
# 593           4           140.0  288.0
# 594           4           120.0  336.0
# 595           4           135.0  491.0
# 596           4           150.0  222.0
